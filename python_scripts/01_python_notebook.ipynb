# %% [markdown]
# ## Python Scripts for the Bellabeat Analysis

# %%
import numpy as np
import pandas as pd
import plotly.express as px
from pathlib import Path


data_file = Path(r'C:\Users\keith\Desktop\DATA ANALYTICS\0.2 GOOGLE COURSE\CAPSTONE PROJECT\Fitbit_Exercise_Data_Analysis\ANALYSIS\sql_saved_tables\01_sedentary_vs_active_time.csv')

df = pd.read_csv(data_file)

fig  = px.bar(df, x=df['id'],y=df['sedentary_active_ratio'])
fig.show()
